# %% [markdown]
# <a href="https://colab.research.google.com/github/vvithurshan/DeepLearning/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-clsna_vn
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-clsna_vn
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=7117bbc3bf8ab5b889eecc9d167de52505b1ec6293a6f5714faa633bc9d38eb8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cdaw536e/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
)


def weights_init(layer):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer, torch.nn.Linear):
        torch.nn.init.kaiming_uniform_(layer.weight.data, nonlinearity='relu')
        if layer.bias is not None:
            torch.nn.init.zeros_(layer.bias.data)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.576343, train error 60.30,  test loss 1.654820, test error 66.60
# Epoch     1, train loss 1.324713, train error 48.62,  test loss 1.467476, test error 58.10
# Epoch     2, train loss 1.128251, train error 40.40,  test loss 1.325181, test error 49.70
# Epoch     3, train loss 0.989178, train error 35.80,  test loss 1.269478, test error 48.40
# Epoch     4, train loss 0.890956, train error 31.95,  test loss 1.212933, test error 45.60
# Epoch     5, train loss 0.800833, train error 29.00,  test loss 1.180636, test error 45.60
# Epoch     6, train loss 0.710498, train error 24.40,  test loss 1.110913, test error 42.20
# Epoch     7, train loss 0.659926, train error 22.30,  test loss 1.113627, test error 42.50
# Epoch     8, train loss 0.615429, train error 21.32,  test loss 1.146761, test error 42.00
# Epoch     9, train loss 0.532044, train error 18.95,  test loss 1.098450, test error 41.50
# Epoch    10, train loss 0.421098, train error 12.95,  test loss 1.051808, test error 38.80
# Epoch    11, train loss 0.379117, train error 10.78,  test loss 1.061010, test error 40.90
# Epoch    12, train loss 0.343553, train error 9.25,  test loss 1.057595, test error 38.40
# Epoch    13, train loss 0.317863, train error 8.18,  test loss 1.095665, test error 39.70
# Epoch    14, train loss 0.307837, train error 8.35,  test loss 1.084268, test error 40.20
# Epoch    15, train loss 0.261461, train error 5.70,  test loss 1.119666, test error 40.00
# Epoch    16, train loss 0.239384, train error 4.95,  test loss 1.132641, test error 40.10
# Epoch    17, train loss 0.229002, train error 5.03,  test loss 1.105681, test error 38.70
# Epoch    18, train loss 0.201534, train error 4.00,  test loss 1.137882, test error 38.50
# Epoch    19, train loss 0.176680, train error 2.90,  test loss 1.159314, test error 38.70
# Epoch    20, train loss 0.155585, train error 1.78,  test loss 1.173483, test error 39.60
# Epoch    21, train loss 0.142415, train error 1.45,  test loss 1.165226, test error 38.10
# Epoch    22, train loss 0.133979, train error 1.15,  test loss 1.168845, test error 38.20
# Epoch    23, train loss 0.125960, train error 0.95,  test loss 1.188131, test error 38.50
# Epoch    24, train loss 0.120155, train error 1.00,  test loss 1.191029, test error 38.10
# Epoch    25, train loss 0.113257, train error 0.75,  test loss 1.206828, test error 38.00
# Epoch    26, train loss 0.107561, train error 0.72,  test loss 1.227536, test error 38.30
# Epoch    27, train loss 0.102941, train error 0.62,  test loss 1.232625, test error 38.20
# Epoch    28, train loss 0.100372, train error 0.72,  test loss 1.240348, test error 38.20
# Epoch    29, train loss 0.095418, train error 0.65,  test loss 1.261078, test error 38.30
# Epoch    30, train loss 0.088357, train error 0.30,  test loss 1.254717, test error 38.00
# Epoch    31, train loss 0.085893, train error 0.25,  test loss 1.255860, test error 37.50
# Epoch    32, train loss 0.084912, train error 0.28,  test loss 1.259805, test error 37.80
# Epoch    33, train loss 0.082007, train error 0.25,  test loss 1.271030, test error 37.80
# Epoch    34, train loss 0.080008, train error 0.25,  test loss 1.282112, test error 37.60
# Epoch    35, train loss 0.077888, train error 0.22,  test loss 1.277796, test error 37.20
# Epoch    36, train loss 0.076895, train error 0.12,  test loss 1.291512, test error 37.60
# Epoch    37, train loss 0.074579, train error 0.15,  test loss 1.287527, test error 38.00
# Epoch    38, train loss 0.072816, train error 0.10,  test loss 1.300313, test error 37.40
# Epoch    39, train loss 0.071085, train error 0.10,  test loss 1.300786, test error 37.40
# Epoch    40, train loss 0.069934, train error 0.10,  test loss 1.305917, test error 37.90
# Epoch    41, train loss 0.068996, train error 0.10,  test loss 1.307275, test error 37.50
# Epoch    42, train loss 0.068304, train error 0.10,  test loss 1.310727, test error 37.80
# Epoch    43, train loss 0.067467, train error 0.10,  test loss 1.314606, test error 37.30
# Epoch    44, train loss 0.066767, train error 0.07,  test loss 1.317371, test error 37.60
# Epoch    45, train loss 0.065997, train error 0.07,  test loss 1.321311, test error 37.60
# Epoch    46, train loss 0.065502, train error 0.07,  test loss 1.322974, test error 37.60
# Epoch    47, train loss 0.064628, train error 0.05,  test loss 1.326084, test error 37.50
# Epoch    48, train loss 0.063962, train error 0.07,  test loss 1.327722, test error 37.40
# Epoch    49, train loss 0.063312, train error 0.05,  test loss 1.328008, test error 37.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
