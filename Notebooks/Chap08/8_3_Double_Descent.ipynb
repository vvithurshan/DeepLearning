# %% [markdown]
# <a href="https://colab.research.google.com/github/vvithurshan/DeepLearning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-lrtmzmhy
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-lrtmzmhy
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=f89507fb2a7540166852d72f45ff0049267b0e6abe959dfe3356b7fd899e24b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uk5vc5id/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# 1. Nearly at 50
# 2. Nearly at 50
# 3. Nearly at 50

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302755, train error 89.82,  test loss 2.302949, test error 90.28
# Epoch   100, train loss 2.302364, train error 89.65,  test loss 2.302866, test error 89.88
# Epoch   200, train loss 2.302357, train error 89.65,  test loss 2.303036, test error 89.88
# Epoch   300, train loss 2.302360, train error 89.72,  test loss 2.302932, test error 90.30
# Epoch   400, train loss 2.302356, train error 89.65,  test loss 2.303000, test error 89.88
# Epoch   500, train loss 2.302357, train error 89.65,  test loss 2.302999, test error 89.88
# Epoch   600, train loss 2.302362, train error 89.65,  test loss 2.302910, test error 89.88
# Epoch   700, train loss 2.302356, train error 89.65,  test loss 2.302944, test error 89.88
# Epoch   800, train loss 2.302356, train error 89.65,  test loss 2.302987, test error 89.88
# Epoch   900, train loss 2.302358, train error 89.65,  test loss 2.302854, test error 89.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301449, train error 88.95,  test loss 2.300844, test error 89.30
# Epoch   100, train loss 1.738881, train error 61.70,  test loss 1.541096, test error 58.95
# Epoch   200, train loss 1.720040, train error 62.15,  test loss 1.515578, test error 58.40
# Epoch   300, train loss 1.715220, train error 61.47,  test loss 1.512892, test error 57.67
# Epoch   400, train loss 1.712721, train error 61.78,  test loss 1.512726, test error 58.70
# Epoch   500, train loss 1.710649, train error 62.20,  test loss 1.502534, test error 59.03
# Epoch   600, train loss 1.708513, train error 61.22,  test loss 1.502771, test error 58.47
# Epoch   700, train loss 1.711774, train error 61.50,  test loss 1.505947, test error 58.10
# Epoch   800, train loss 1.712593, train error 62.08,  test loss 1.497863, test error 58.28
# Epoch   900, train loss 1.711094, train error 61.83,  test loss 1.507235, test error 58.45
# Training model with   6 hidden variables
# Epoch     0, train loss 2.165726, train error 83.45,  test loss 2.130098, test error 82.68
# Epoch   100, train loss 1.688748, train error 60.05,  test loss 1.512764, test error 58.28
# Epoch   200, train loss 1.647819, train error 57.58,  test loss 1.471987, test error 57.10
# Epoch   300, train loss 1.614184, train error 57.45,  test loss 1.445895, test error 55.55
# Epoch   400, train loss 1.606176, train error 57.22,  test loss 1.455078, test error 55.30
# Epoch   500, train loss 1.597168, train error 57.67,  test loss 1.448929, test error 55.92
# Epoch   600, train loss 1.592610, train error 57.78,  test loss 1.451569, test error 54.90
# Epoch   700, train loss 1.591916, train error 57.15,  test loss 1.460689, test error 56.42
# Epoch   800, train loss 1.582912, train error 56.58,  test loss 1.451438, test error 56.15
# Epoch   900, train loss 1.592165, train error 57.58,  test loss 1.454140, test error 56.20
# Training model with   8 hidden variables
# Epoch     0, train loss 2.214801, train error 82.30,  test loss 2.190970, test error 81.22
# Epoch   100, train loss 1.523528, train error 52.15,  test loss 1.330963, test error 49.28
# Epoch   200, train loss 1.484791, train error 49.85,  test loss 1.288935, test error 47.75
# Epoch   300, train loss 1.459145, train error 49.20,  test loss 1.266229, test error 46.45
# Epoch   400, train loss 1.450730, train error 49.08,  test loss 1.268505, test error 46.50
# Epoch   500, train loss 1.443896, train error 48.60,  test loss 1.266261, test error 46.83
# Epoch   600, train loss 1.432723, train error 48.65,  test loss 1.271556, test error 46.75
# Epoch   700, train loss 1.429810, train error 48.53,  test loss 1.273386, test error 46.95
# Epoch   800, train loss 1.421600, train error 48.28,  test loss 1.261448, test error 46.22
# Epoch   900, train loss 1.419766, train error 48.12,  test loss 1.257567, test error 46.58
# Training model with  10 hidden variables
# Epoch     0, train loss 2.246191, train error 85.07,  test loss 2.248018, test error 85.93
# Epoch   100, train loss 1.548883, train error 54.30,  test loss 1.430514, test error 55.17
# Epoch   200, train loss 1.489028, train error 52.38,  test loss 1.416809, test error 53.42
# Epoch   300, train loss 1.468547, train error 51.17,  test loss 1.421528, test error 52.45
# Epoch   400, train loss 1.448784, train error 49.75,  test loss 1.396225, test error 50.83
# Epoch   500, train loss 1.436535, train error 50.20,  test loss 1.390756, test error 51.40
# Epoch   600, train loss 1.441239, train error 50.25,  test loss 1.384604, test error 50.65
# Epoch   700, train loss 1.428459, train error 50.10,  test loss 1.377517, test error 50.30
# Epoch   800, train loss 1.423763, train error 49.67,  test loss 1.378578, test error 50.58
# Epoch   900, train loss 1.419176, train error 49.20,  test loss 1.383340, test error 51.17
# Training model with  14 hidden variables
# Epoch     0, train loss 2.207539, train error 81.18,  test loss 2.193756, test error 82.12
# Epoch   100, train loss 1.437905, train error 48.47,  test loss 1.325189, test error 49.35
# Epoch   200, train loss 1.374087, train error 46.42,  test loss 1.332654, test error 49.95
# Epoch   300, train loss 1.349573, train error 44.97,  test loss 1.358744, test error 50.35
# Epoch   400, train loss 1.337817, train error 45.15,  test loss 1.364963, test error 49.97
# Epoch   500, train loss 1.317204, train error 44.62,  test loss 1.373317, test error 49.95
# Epoch   600, train loss 1.301409, train error 43.92,  test loss 1.393599, test error 50.30
# Epoch   700, train loss 1.299663, train error 43.55,  test loss 1.395034, test error 49.78
# Epoch   800, train loss 1.297247, train error 43.35,  test loss 1.419402, test error 50.75
# Epoch   900, train loss 1.287858, train error 43.33,  test loss 1.436784, test error 51.00
# Training model with  18 hidden variables
# Epoch     0, train loss 2.276337, train error 83.47,  test loss 2.284480, test error 83.70
# Epoch   100, train loss 1.367145, train error 46.65,  test loss 1.350993, test error 51.22
# Epoch   200, train loss 1.267012, train error 42.75,  test loss 1.320355, test error 48.75
# Epoch   300, train loss 1.213369, train error 40.33,  test loss 1.346228, test error 49.12
# Epoch   400, train loss 1.178544, train error 39.85,  test loss 1.373656, test error 49.50
# Epoch   500, train loss 1.157720, train error 39.53,  test loss 1.410652, test error 49.78
# Epoch   600, train loss 1.146790, train error 39.30,  test loss 1.442669, test error 49.72
# Epoch   700, train loss 1.142711, train error 39.40,  test loss 1.469961, test error 49.65
# Epoch   800, train loss 1.129715, train error 38.55,  test loss 1.478923, test error 49.28
# Epoch   900, train loss 1.120581, train error 37.83,  test loss 1.495701, test error 49.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.113903, train error 78.70,  test loss 2.075609, test error 78.82
# Epoch   100, train loss 1.249549, train error 41.97,  test loss 1.301901, test error 47.67
# Epoch   200, train loss 1.137046, train error 37.30,  test loss 1.357973, test error 49.95
# Epoch   300, train loss 1.086836, train error 35.90,  test loss 1.424467, test error 50.72
# Epoch   400, train loss 1.052373, train error 35.65,  test loss 1.501063, test error 52.75
# Epoch   500, train loss 1.018634, train error 34.03,  test loss 1.558158, test error 52.42
# Epoch   600, train loss 0.999300, train error 33.22,  test loss 1.589959, test error 52.50
# Epoch   700, train loss 0.990681, train error 33.55,  test loss 1.655117, test error 52.25
# Epoch   800, train loss 0.977389, train error 32.15,  test loss 1.673575, test error 52.22
# Epoch   900, train loss 0.970934, train error 32.30,  test loss 1.742552, test error 52.33
# Training model with  26 hidden variables
# Epoch     0, train loss 2.206842, train error 82.60,  test loss 2.201638, test error 81.85
# Epoch   100, train loss 1.203699, train error 39.85,  test loss 1.315558, test error 48.58
# Epoch   200, train loss 1.070004, train error 35.57,  test loss 1.457114, test error 50.17
# Epoch   300, train loss 0.968387, train error 32.22,  test loss 1.574562, test error 51.92
# Epoch   400, train loss 0.926885, train error 30.78,  test loss 1.687883, test error 51.95
# Epoch   500, train loss 0.894163, train error 29.80,  test loss 1.792589, test error 53.22
# Epoch   600, train loss 0.889601, train error 30.47,  test loss 1.903649, test error 54.10
# Epoch   700, train loss 0.870706, train error 29.45,  test loss 1.959174, test error 54.08
# Epoch   800, train loss 0.834830, train error 28.25,  test loss 2.033087, test error 54.70
# Epoch   900, train loss 0.849412, train error 29.43,  test loss 2.126288, test error 55.67
# Training model with  30 hidden variables
# Epoch     0, train loss 2.197013, train error 81.40,  test loss 2.168225, test error 80.97
# Epoch   100, train loss 1.105570, train error 36.97,  test loss 1.323798, test error 47.53
# Epoch   200, train loss 0.913472, train error 30.10,  test loss 1.590042, test error 50.28
# Epoch   300, train loss 0.823305, train error 27.62,  test loss 1.829152, test error 51.83
# Epoch   400, train loss 0.770328, train error 25.68,  test loss 2.022401, test error 53.88
# Epoch   500, train loss 0.744531, train error 25.57,  test loss 2.194526, test error 55.08
# Epoch   600, train loss 0.716456, train error 24.90,  test loss 2.362243, test error 55.30
# Epoch   700, train loss 0.699317, train error 24.32,  test loss 2.530124, test error 55.85
# Epoch   800, train loss 0.666312, train error 23.12,  test loss 2.648606, test error 55.78
# Epoch   900, train loss 0.661974, train error 23.45,  test loss 2.812136, test error 56.75
# Training model with  35 hidden variables
# Epoch     0, train loss 2.055070, train error 77.72,  test loss 1.970722, test error 76.57
# Epoch   100, train loss 1.010181, train error 33.38,  test loss 1.420842, test error 50.10
# Epoch   200, train loss 0.798702, train error 25.88,  test loss 1.724317, test error 51.00
# Epoch   300, train loss 0.698476, train error 23.22,  test loss 2.050137, test error 53.95
# Epoch   400, train loss 0.589150, train error 19.45,  test loss 2.407788, test error 55.08
# Epoch   500, train loss 0.575772, train error 20.00,  test loss 2.808471, test error 56.10
# Epoch   600, train loss 0.509070, train error 16.93,  test loss 2.984122, test error 54.85
# Epoch   700, train loss 0.499726, train error 17.38,  test loss 3.297148, test error 55.85
# Epoch   800, train loss 0.472728, train error 16.97,  test loss 3.614666, test error 56.90
# Epoch   900, train loss 0.457862, train error 15.90,  test loss 3.783823, test error 56.85
# Training model with  40 hidden variables
# Epoch     0, train loss 2.084825, train error 78.20,  test loss 2.032103, test error 77.30
# Epoch   100, train loss 0.947051, train error 29.88,  test loss 1.459487, test error 51.15
# Epoch   200, train loss 0.650010, train error 20.97,  test loss 1.919958, test error 53.50
# Epoch   300, train loss 0.486625, train error 15.55,  test loss 2.535918, test error 55.38
# Epoch   400, train loss 0.407711, train error 13.53,  test loss 3.252403, test error 55.28
# Epoch   500, train loss 0.384376, train error 13.80,  test loss 3.984227, test error 56.85
# Epoch   600, train loss 0.305639, train error 10.72,  test loss 4.703485, test error 57.00
# Epoch   700, train loss 0.291017, train error 10.07,  test loss 5.361186, test error 56.67
# Epoch   800, train loss 0.306814, train error 10.93,  test loss 6.079645, test error 57.28
# Epoch   900, train loss 0.295369, train error 10.55,  test loss 6.659674, test error 56.97
# Training model with  45 hidden variables
# Epoch     0, train loss 2.097235, train error 78.78,  test loss 2.060780, test error 79.32
# Epoch   100, train loss 0.850612, train error 26.85,  test loss 1.441651, test error 48.90
# Epoch   200, train loss 0.490676, train error 15.25,  test loss 2.142699, test error 52.40
# Epoch   300, train loss 0.361258, train error 11.88,  test loss 3.201374, test error 55.33
# Epoch   400, train loss 0.187918, train error 5.28,  test loss 4.281904, test error 54.17
# Epoch   500, train loss 0.180859, train error 6.57,  test loss 5.705662, test error 56.30
# Epoch   600, train loss 0.082290, train error 2.03,  test loss 6.895676, test error 56.42
# Epoch   700, train loss 0.011918, train error 0.00,  test loss 8.032351, test error 57.12
# Epoch   800, train loss 0.006864, train error 0.00,  test loss 8.686337, test error 57.08
# Epoch   900, train loss 0.005133, train error 0.00,  test loss 9.141858, test error 57.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.148507, train error 78.55,  test loss 2.135252, test error 77.35
# Epoch   100, train loss 0.733097, train error 22.05,  test loss 1.603002, test error 50.40
# Epoch   200, train loss 0.351242, train error 9.88,  test loss 2.610503, test error 53.78
# Epoch   300, train loss 0.175704, train error 4.35,  test loss 4.076056, test error 55.83
# Epoch   400, train loss 0.042783, train error 0.05,  test loss 5.718460, test error 56.85
# Epoch   500, train loss 0.178941, train error 6.20,  test loss 6.971223, test error 58.58
# Epoch   600, train loss 0.008489, train error 0.00,  test loss 7.532956, test error 57.12
# Epoch   700, train loss 0.005861, train error 0.00,  test loss 8.032502, test error 56.97
# Epoch   800, train loss 0.004447, train error 0.00,  test loss 8.415515, test error 56.95
# Epoch   900, train loss 0.003584, train error 0.00,  test loss 8.733983, test error 57.00
# Training model with  55 hidden variables
# Epoch     0, train loss 2.075412, train error 77.25,  test loss 2.046911, test error 78.32
# Epoch   100, train loss 0.644436, train error 20.07,  test loss 1.640635, test error 49.72
# Epoch   200, train loss 0.219283, train error 5.25,  test loss 3.050969, test error 53.95
# Epoch   300, train loss 0.042528, train error 0.07,  test loss 4.681464, test error 54.58
# Epoch   400, train loss 0.015064, train error 0.00,  test loss 5.729652, test error 55.12
# Epoch   500, train loss 0.008629, train error 0.00,  test loss 6.339045, test error 55.08
# Epoch   600, train loss 0.005861, train error 0.00,  test loss 6.778689, test error 55.05
# Epoch   700, train loss 0.004433, train error 0.00,  test loss 7.119645, test error 55.30
# Epoch   800, train loss 0.003456, train error 0.00,  test loss 7.391501, test error 55.22
# Epoch   900, train loss 0.002838, train error 0.00,  test loss 7.632013, test error 55.38
# Training model with  60 hidden variables
# Epoch     0, train loss 2.108981, train error 78.28,  test loss 2.070769, test error 77.88
# Epoch   100, train loss 0.558361, train error 16.55,  test loss 1.805313, test error 52.00
# Epoch   200, train loss 0.122563, train error 1.32,  test loss 3.631411, test error 56.15
# Epoch   300, train loss 0.022220, train error 0.00,  test loss 5.183364, test error 56.70
# Epoch   400, train loss 0.010200, train error 0.00,  test loss 5.964689, test error 56.50
# Epoch   500, train loss 0.006360, train error 0.00,  test loss 6.479022, test error 56.60
# Epoch   600, train loss 0.004514, train error 0.00,  test loss 6.858171, test error 56.72
# Epoch   700, train loss 0.003450, train error 0.00,  test loss 7.154636, test error 56.90
# Epoch   800, train loss 0.002762, train error 0.00,  test loss 7.398466, test error 56.90
# Epoch   900, train loss 0.002294, train error 0.00,  test loss 7.606126, test error 56.92
# Training model with  70 hidden variables
# Epoch     0, train loss 2.057556, train error 75.72,  test loss 1.992346, test error 74.72
# Epoch   100, train loss 0.359724, train error 8.72,  test loss 2.006031, test error 53.00
# Epoch   200, train loss 0.033169, train error 0.05,  test loss 3.631042, test error 53.92
# Epoch   300, train loss 0.011265, train error 0.00,  test loss 4.475066, test error 54.28
# Epoch   400, train loss 0.006229, train error 0.00,  test loss 4.929595, test error 54.30
# Epoch   500, train loss 0.004192, train error 0.00,  test loss 5.252364, test error 54.42
# Epoch   600, train loss 0.003099, train error 0.00,  test loss 5.494147, test error 54.17
# Epoch   700, train loss 0.002429, train error 0.00,  test loss 5.694034, test error 54.20
# Epoch   800, train loss 0.001981, train error 0.00,  test loss 5.860518, test error 54.25
# Epoch   900, train loss 0.001665, train error 0.00,  test loss 6.005559, test error 54.20
# Training model with  80 hidden variables
# Epoch     0, train loss 2.076162, train error 77.15,  test loss 2.046237, test error 76.80
# Epoch   100, train loss 0.247755, train error 4.53,  test loss 2.003655, test error 50.97
# Epoch   200, train loss 0.021143, train error 0.00,  test loss 3.340696, test error 51.88
# Epoch   300, train loss 0.008444, train error 0.00,  test loss 3.906553, test error 52.15
# Epoch   400, train loss 0.004960, train error 0.00,  test loss 4.237013, test error 52.38
# Epoch   500, train loss 0.003424, train error 0.00,  test loss 4.469345, test error 52.30
# Epoch   600, train loss 0.002578, train error 0.00,  test loss 4.652018, test error 52.40
# Epoch   700, train loss 0.002046, train error 0.00,  test loss 4.799637, test error 52.53
# Epoch   800, train loss 0.001682, train error 0.00,  test loss 4.924287, test error 52.55
# Epoch   900, train loss 0.001422, train error 0.00,  test loss 5.032236, test error 52.62
# Training model with  90 hidden variables
# Epoch     0, train loss 2.009734, train error 74.95,  test loss 1.948224, test error 73.72
# Epoch   100, train loss 0.131310, train error 0.72,  test loss 2.286948, test error 51.08
# Epoch   200, train loss 0.014411, train error 0.00,  test loss 3.372455, test error 51.65
# Epoch   300, train loss 0.006475, train error 0.00,  test loss 3.816192, test error 51.67
# Epoch   400, train loss 0.003954, train error 0.00,  test loss 4.098641, test error 51.90
# Epoch   500, train loss 0.002783, train error 0.00,  test loss 4.295853, test error 51.83
# Epoch   600, train loss 0.002120, train error 0.00,  test loss 4.450383, test error 51.90
# Epoch   700, train loss 0.001696, train error 0.00,  test loss 4.577235, test error 52.05
# Epoch   800, train loss 0.001404, train error 0.00,  test loss 4.685383, test error 52.08
# Epoch   900, train loss 0.001192, train error 0.00,  test loss 4.777438, test error 52.10
# Training model with 100 hidden variables
# Epoch     0, train loss 2.006145, train error 74.05,  test loss 1.949025, test error 75.22
# Epoch   100, train loss 0.105899, train error 0.62,  test loss 2.143703, test error 50.03
# Epoch   200, train loss 0.012791, train error 0.00,  test loss 3.018610, test error 50.33
# Epoch   300, train loss 0.005882, train error 0.00,  test loss 3.388157, test error 50.42
# Epoch   400, train loss 0.003652, train error 0.00,  test loss 3.615874, test error 50.53
# Epoch   500, train loss 0.002581, train error 0.00,  test loss 3.782731, test error 50.55
# Epoch   600, train loss 0.001970, train error 0.00,  test loss 3.913671, test error 50.58
# Epoch   700, train loss 0.001580, train error 0.00,  test loss 4.020025, test error 50.50
# Epoch   800, train loss 0.001311, train error 0.00,  test loss 4.111714, test error 50.40
# Epoch   900, train loss 0.001116, train error 0.00,  test loss 4.190459, test error 50.53
# Training model with 120 hidden variables
# Epoch     0, train loss 1.988151, train error 73.93,  test loss 1.923538, test error 74.22
# Epoch   100, train loss 0.052375, train error 0.03,  test loss 2.312976, test error 51.78
# Epoch   200, train loss 0.009628, train error 0.00,  test loss 2.944589, test error 52.85
# Epoch   300, train loss 0.004769, train error 0.00,  test loss 3.237374, test error 52.70
# Epoch   400, train loss 0.003058, train error 0.00,  test loss 3.421224, test error 52.55
# Epoch   500, train loss 0.002208, train error 0.00,  test loss 3.557340, test error 52.70
# Epoch   600, train loss 0.001706, train error 0.00,  test loss 3.665437, test error 52.72
# Epoch   700, train loss 0.001380, train error 0.00,  test loss 3.754120, test error 52.67
# Epoch   800, train loss 0.001152, train error 0.00,  test loss 3.829491, test error 52.70
# Epoch   900, train loss 0.000985, train error 0.00,  test loss 3.895516, test error 52.78
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952258, train error 71.72,  test loss 1.874281, test error 72.90
# Epoch   100, train loss 0.036115, train error 0.00,  test loss 2.224822, test error 49.75
# Epoch   200, train loss 0.008100, train error 0.00,  test loss 2.749330, test error 50.45
# Epoch   300, train loss 0.004138, train error 0.00,  test loss 2.990280, test error 50.58
# Epoch   400, train loss 0.002685, train error 0.00,  test loss 3.149051, test error 50.42
# Epoch   500, train loss 0.001950, train error 0.00,  test loss 3.267756, test error 50.58
# Epoch   600, train loss 0.001514, train error 0.00,  test loss 3.361324, test error 50.72
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.439008, test error 50.72
# Epoch   800, train loss 0.001028, train error 0.00,  test loss 3.505798, test error 50.70
# Epoch   900, train loss 0.000881, train error 0.00,  test loss 3.564218, test error 50.78
# Training model with 160 hidden variables
# Epoch     0, train loss 1.922655, train error 70.80,  test loss 1.864574, test error 72.85
# Epoch   100, train loss 0.028417, train error 0.00,  test loss 2.235489, test error 51.28
# Epoch   200, train loss 0.007191, train error 0.00,  test loss 2.666365, test error 51.17
# Epoch   300, train loss 0.003779, train error 0.00,  test loss 2.878389, test error 51.28
# Epoch   400, train loss 0.002485, train error 0.00,  test loss 3.018529, test error 51.45
# Epoch   500, train loss 0.001818, train error 0.00,  test loss 3.125005, test error 51.47
# Epoch   600, train loss 0.001419, train error 0.00,  test loss 3.209064, test error 51.45
# Epoch   700, train loss 0.001155, train error 0.00,  test loss 3.279911, test error 51.47
# Epoch   800, train loss 0.000970, train error 0.00,  test loss 3.340163, test error 51.38
# Epoch   900, train loss 0.000832, train error 0.00,  test loss 3.392375, test error 51.35
# Training model with 180 hidden variables
# Epoch     0, train loss 1.913298, train error 70.82,  test loss 1.851633, test error 72.28
# Epoch   100, train loss 0.023458, train error 0.00,  test loss 2.017361, test error 47.05
# Epoch   200, train loss 0.006477, train error 0.00,  test loss 2.354817, test error 47.22
# Epoch   300, train loss 0.003491, train error 0.00,  test loss 2.528223, test error 47.25
# Epoch   400, train loss 0.002319, train error 0.00,  test loss 2.643929, test error 47.17
# Epoch   500, train loss 0.001708, train error 0.00,  test loss 2.731393, test error 47.17
# Epoch   600, train loss 0.001339, train error 0.00,  test loss 2.800701, test error 47.15
# Epoch   700, train loss 0.001094, train error 0.00,  test loss 2.858273, test error 47.00
# Epoch   800, train loss 0.000920, train error 0.00,  test loss 2.908089, test error 46.97
# Epoch   900, train loss 0.000791, train error 0.00,  test loss 2.951701, test error 46.97
# Training model with 200 hidden variables
# Epoch     0, train loss 1.908579, train error 69.32,  test loss 1.856397, test error 72.43
# Epoch   100, train loss 0.020658, train error 0.00,  test loss 2.013872, test error 48.75
# Epoch   200, train loss 0.005972, train error 0.00,  test loss 2.321904, test error 48.62
# Epoch   300, train loss 0.003242, train error 0.00,  test loss 2.478487, test error 48.55
# Epoch   400, train loss 0.002165, train error 0.00,  test loss 2.586695, test error 48.75
# Epoch   500, train loss 0.001601, train error 0.00,  test loss 2.667888, test error 48.70
# Epoch   600, train loss 0.001259, train error 0.00,  test loss 2.733326, test error 48.67
# Epoch   700, train loss 0.001031, train error 0.00,  test loss 2.787527, test error 48.67
# Epoch   800, train loss 0.000868, train error 0.00,  test loss 2.834540, test error 48.60
# Epoch   900, train loss 0.000748, train error 0.00,  test loss 2.875427, test error 48.58
# Training model with 250 hidden variables
# Epoch     0, train loss 1.888597, train error 69.07,  test loss 1.821590, test error 70.43
# Epoch   100, train loss 0.017272, train error 0.00,  test loss 1.889534, test error 46.72
# Epoch   200, train loss 0.005404, train error 0.00,  test loss 2.135322, test error 46.47
# Epoch   300, train loss 0.003008, train error 0.00,  test loss 2.267519, test error 46.42
# Epoch   400, train loss 0.002027, train error 0.00,  test loss 2.358766, test error 46.50
# Epoch   500, train loss 0.001509, train error 0.00,  test loss 2.426764, test error 46.47
# Epoch   600, train loss 0.001190, train error 0.00,  test loss 2.482649, test error 46.50
# Epoch   700, train loss 0.000977, train error 0.00,  test loss 2.529011, test error 46.58
# Epoch   800, train loss 0.000824, train error 0.00,  test loss 2.569021, test error 46.50
# Epoch   900, train loss 0.000711, train error 0.00,  test loss 2.604039, test error 46.45
# Training model with 300 hidden variables
# Epoch     0, train loss 1.867689, train error 66.38,  test loss 1.798751, test error 68.65
# Epoch   100, train loss 0.014480, train error 0.00,  test loss 1.842631, test error 46.70
# Epoch   200, train loss 0.004828, train error 0.00,  test loss 2.064125, test error 46.58
# Epoch   300, train loss 0.002737, train error 0.00,  test loss 2.186096, test error 46.62
# Epoch   400, train loss 0.001864, train error 0.00,  test loss 2.270672, test error 46.72
# Epoch   500, train loss 0.001395, train error 0.00,  test loss 2.334652, test error 46.88
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.386995, test error 46.97
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.430367, test error 46.88
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.467690, test error 46.78
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.500672, test error 46.78
# Training model with 400 hidden variables
# Epoch     0, train loss 1.871447, train error 67.18,  test loss 1.797929, test error 68.00
# Epoch   100, train loss 0.011610, train error 0.00,  test loss 1.766119, test error 45.92
# Epoch   200, train loss 0.004142, train error 0.00,  test loss 1.936292, test error 45.50
# Epoch   300, train loss 0.002398, train error 0.00,  test loss 2.034717, test error 45.55
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.103078, test error 45.62
# Epoch   500, train loss 0.001244, train error 0.00,  test loss 2.154909, test error 45.62
# Epoch   600, train loss 0.000991, train error 0.00,  test loss 2.197529, test error 45.58
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.233872, test error 45.58
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.264454, test error 45.55
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.291516, test error 45.47

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
